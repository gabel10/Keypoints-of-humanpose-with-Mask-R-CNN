# %% [markdown]
# ## Train / Val data augmentation

# %% [markdown]
# Para realizar la división de los datos, primero tenemos que tener lo siguiente en formato de carpetas:
# * Images. carpeta donde están las imágenes en formato JPG de tamaño (640x640)
# * Masks. carpeta donde están las máscaras en formato PNG de tamaño (640x640)
# * file.txt. archivo con la descripción de los nombres de archivo de imagen y el peso del cuy.

# %% [markdown]
# ### División del dataset en conjunto de entrenamiento y validación

# %%
import os
from sklearn.model_selection  import train_test_split
import pandas as pd
import shutil
from PIL import Image

# %%
# Leer el archivo de texto
df = pd.read_csv('C:\\Users\\Yeshica\\Pictures\\dataset\\cuy_bw.txt', header=None)
print('Hay {} imagenes con sus respectivos pesos'.format(len(df)))

# %% [markdown]
# Dividir el documento de texto en uno para el entrenamiento (80%) y otro para la validación (20%). Y los guardamos en la ruta indicada en formato .txt

# %%
train, test = train_test_split(df, test_size=0.2, random_state=7)
train.to_csv(r'C:\\Users\\Yeshica\\Pictures\\dataset\\cuy_train.txt', header=None, index=None, sep=' ', mode='w')
test.to_csv(r'C:\\Users\\Yeshica\\Pictures\\dataset\\cuy_test.txt', header=None, index=None, sep=' ', mode='w')

# %%
# Rutas donde se almacenan las imágenes y las máscaras
path_base = 'C:\\Users\\Yeshica\\Pictures\\dataset\\'
path_image_from = path_base + 'images'
path_mask_from = path_base + 'masks'

# %% [markdown]
# #### Training data

# %%
# rutas para almacenar las imágenes y máscaras de entrenamiento
path_image_to = path_base + 'train_jpg'
path_mask_to = path_base + 'train_mask'
# Creamos las carpetas
os.mkdir(path_image_to)
os.mkdir(path_mask_to)
# Leemos el archivo con los datos de entrenamiento
file = open('C:\\Users\\Yeshica\\Pictures\\dataset\\cuy_train.txt')
lines = file.readlines()
for line in lines:
    filename = line.split(' ')[0]
    shutil.copy(os.path.join(path_image_from, filename), os.path.join(path_image_to, filename))
    maskname = filename.split('.')[0] + '_mask.png'
    shutil.copy(os.path.join(path_mask_from, maskname), os.path.join(path_mask_to, maskname))

# %% [markdown]
# Convertir de formato las imágenes (JPG a PNG), porque el aumentado se realiza en este formato.

# %%
path_from = 'C:\\Users\\Yeshica\\Pictures\\dataset\\train_jpg'
path_to = 'C:\\Users\\Yeshica\\Pictures\\dataset\\train_png'
os.mkdir(path_to)
image_file_list = os.listdir(path_from)
for image_file in image_file_list:
    im = Image.open(os.path.join(path_from, image_file))
    filename =  os.path.splitext(os.path.basename(image_file))[0] + '.png'
    im.save(os.path.join(path_to, filename))

# %% [markdown]
# Luego, debemos reemplazar todas las extensiones (.jpg) del archivo .txt para continuar con el aumento de datos. Para el aumento de datos se necesita la ruta de entrada que contenga dos carpetas (images y masks con las imágenes y máscaras respectivamente), además de una carpeta de salida existente, el número de aumentaciones y el archivo donde se estan los nombres de archivos y pesos.

# %%
# !python augmentation.py -id C:\Users\Yeshica\Pictures\dataset\train -od C:\Users\Yeshica\Pictures\dataset\train_aug -na 3 -file C:\Users\Yeshica\Pictures\dataset\cuy_train_se.txt

# %% [markdown]
# Luego se procede a volver a convertir los archivos PNG a JPG porque el tamaño de PNG es muy grande frente al tamaño de un archivo JPG.

# %%
path_from = 'C:\\Users\\Yeshica\\Pictures\\dataset\\images_png'
path_to = 'C:\\Users\\Yeshica\\Pictures\\dataset\\images_jpg'
image_file_list = os.listdir(path_from)
for image_file in image_file_list:
    im = Image.open(os.path.join(path_from, image_file))
    filename =  os.path.splitext(os.path.basename(image_file))[0] + '.jpg'
    rgb_im = im.convert('RGB')
    rgb_im.save(os.path.join(path_to, filename), quality=95)

# %% [markdown]
# #### Validation data

# %%
# rutas para almacenar las imágenes y máscara de validación
path_image_to = path_base + 'val_jpg'
path_mask_to = path_base + 'val_mask'
# creamos las carpetas
os.mkdir(path_image_to)
os.mkdir(path_mask_to)
# leemos el archivo con los datos de validación
file = open('C:\\Users\\Yeshica\\Pictures\\dataset\\cuy_test.txt')
lines = file.readlines()
for line in lines:
    filename = line.split(' ')[0]
    shutil.copy(os.path.join(path_image_from, filename), os.path.join(path_image_to, filename))
    maskname = filename.split('.')[0] + '_mask.png'
    shutil.copy(os.path.join(path_mask_from, maskname), os.path.join(path_mask_to, maskname))

# %% [markdown]
# Convertir de formato las imágenes (JPG a PNG), porque el aumentado se realiza en este formato.

# %%
path_from = 'C:\\Users\\Yeshica\\Pictures\\dataset\\train_jpg'
path_to = 'C:\\Users\\Yeshica\\Pictures\\dataset\\train_png'
os.mkdir(path_to)
image_file_list = os.listdir(path_from)
for image_file in image_file_list:
    im = Image.open(os.path.join(path_from, image_file))
    filename =  os.path.splitext(os.path.basename(image_file))[0] + '.png'
    im.save(os.path.join(path_to, filename))

# %% [markdown]
# Luego, debemos reemplazar todas las extensiones (.jpg) del archivo .txt para continuar con el aumento de datos. Para el aumento de datos se necesita la ruta de entrada que contenga dos carpetas (images y masks con las imágenes y máscaras respectivamente), además de una carpeta de salida existente, el número de aumentaciones y el archivo donde se estan los nombres de archivos y pesos.

# %%
# !python augmentation.py -id C:\Users\Yeshica\Pictures\dataset\val -od C:\Users\Yeshica\Pictures\dataset\val_aug -na 3 -file C:\Users\Yeshica\Pictures\dataset\cuy_test_se.txt
# Out:
# processing DSC_0305.png (1 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0312.png (2 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0318.png (3 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0320.png (4 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0324.png (5 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0327.png (6 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0330.png (7 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0331.png (8 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0333.png (9 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0334.png (10 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0342.png (11 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0347.png (12 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0356.png (13 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0359.png (14 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0364.png (15 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0369.png (16 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0373.png (17 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0376.png (18 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0383.png (19 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0393.png (20 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0425.png (21 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0430.png (22 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0431.png (23 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0433.png (24 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0442.png (25 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0445.png (26 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0446.png (27 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0448.png (28 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0451.png (29 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0452.png (30 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0456.png (31 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0467.png (32 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0468.png (33 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0481.png (34 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0482.png (35 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0487.png (36 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0489.png (37 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0494.png (38 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0510.png (39 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0516.png (40 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0522.png (41 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0530.png (42 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_0537.png (43 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing DSC_
of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_103600.png (205 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_103609.png (206 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_103629.png (207 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_103808.png (208 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_103820.png (209 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_104100.png (210 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_104301.png (211 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_104316.png (212 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_104743.png (213 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_105001.png (214 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_105045.png (215 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_105336.png (216 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_105553.png (217 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_105559.png (218 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_105955.png (219 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_110012.png (220 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_110029.png (221 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_110031.png (222 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_110253.png (223 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_110749.png (224 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210624_111002.png (225 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_142305.png (226 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_142417.png (227 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_142532.png (228 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_142717.png (229 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_142730.png (230 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_142856.png (231 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143020.png (232 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143050.png (233 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143215.png (234 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143216.png (235 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143438.png (236 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143640.png (237 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143739.png (238 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143752.png (239 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_143803.png (240 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144029.png (241 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144032.png (242 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144041.png (243 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144141.png (244 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144143.png (245 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144252.png (246 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144316.png (247 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144435.png (248 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144633.png (249 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144639.png (250 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144845.png (251 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_144858.png (252 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145006.png (253 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145030.png (254 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145111.png (255 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145144.png (256 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145146.png (257 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145313.png (258 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145353.png (259 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145405.png (260 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145409.png (261 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145417.png (262 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145425.png (263 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145435.png (264 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145815.png (265 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145822.png (266 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145824.png (267 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_145827.png (268 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210714_150033.png (269 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_094222.png (270 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_094309.png (271 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_094808.png (272 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_094943.png (273 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_095004.png (274 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_095430.png (275 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_095432.png (276 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_095553.png (277 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_095558.png (278 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_100302.png (279 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_100306.png (280 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210811_100435.png (281 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_155348.png (282 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_155710.png (283 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_161230.png (284 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_161815.png (285 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_161830.png (286 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_163152.png (287 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_163158.png (288 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_163341.png (289 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_163343.png (290 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_163533.png (291 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_163707.png (292 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_165651.png (293 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_165956.png (294 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_170128.png (295 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_171305.png (296 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_171453.png (297 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_172039.png (298 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_172228.png (299 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_172244.png (300 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_172551.png (301 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210812_172604.png (302 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_154354.png (303 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_160033.png (304 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_160038.png (305 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_160208.png (306 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_160716.png (307 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_160751.png (308 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_160829.png (309 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_161838.png (310 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_161857.png (311 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_161913.png (312 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# processing IMG_20210813_162242.png (313 of 313)
# writing out the un-augmented image/mask pair
# writing out the augmented image/mask pair
# completed 3 augmentations for this image.
# augmented set of 1252 images generated from 313 input images

# %% [markdown]
# Luego se procede a volver a convertir los archivos PNG a JPG, porque el tamaño de PNG es muy grande frente al tamaño de un archivo JPG.

# %%
path_from = r'C:\Users\Yeshica\Pictures\dataset\val_aug\images'
path_to = r'C:\Users\Yeshica\Pictures\dataset\val_aug\images_jpg'
image_file_list = os.listdir(path_from)
for image_file in image_file_list:
    im = Image.open(os.path.join(path_from, image_file))
    filename =  os.path.splitext(os.path.basename(image_file))[0] + '.jpg'
    rgb_im = im.convert('RGB')
    rgb_im.save(os.path.join(path_to, filename), quality=95)
