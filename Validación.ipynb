# %% [markdown]
# ## Install required packages

# %%
import os
import cv2
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import skimage
import glob
import utils
import visualize
from visualize import display_images
import model as modellib
from model import log

import cuy

# Root directory of the project
ROOT_DIR = os.getcwd()
#ROOT_DIR = '/root/Mask_RCNN/'
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
# Out:
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Lenovo\anaconda3\envs\maskRCNN\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
custom_WEIGHTS_PATH = r'C:\Users\Lenovo\Documents\logs\cuy20210831T2037_resnet101_2500_mae_v1_imagenet\weight_mask_rcnn_cuy_0050.h5'
dataset_DIR = r"C:\Users\Lenovo\OneDrive\Imágenes\datasetx4"
file_BODYWEIGHT_PATH = os.path.join(dataset_DIR, 'cuy_bw_augmented.txt')

# %%
# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

config = cuy.CuyConfig()

class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()

# Device to load the neural network on.
DEVICE = "/cpu:0"  # /cpu:0 or /gpu:0

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
TEST_MODE = "inference"

def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax
  
# Load validation dataset
dataset = cuy.CuyDataset()
dataset.load_dataset(dataset_DIR, "val", file_BODYWEIGHT_PATH)

# Must call before using the dataset
dataset.prepare()

print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))

# Create model in inference mode
with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights
print("Loading weights ", custom_WEIGHTS_PATH)
model.load_weights(custom_WEIGHTS_PATH, by_name=True)

from importlib import reload # was constantly changin the visualization, so I decided to reload it instead of notebook
reload(visualize)
# Out:
# Configurations Superlee:
# BACKBONE                       resnet101
# BACKBONE_SHAPES                [[160 160]
#  [ 80  80]
#  [ 40  40]
#  [ 20  20]
#  [ 10  10]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        10
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# EPOCHS                         50
# GPU_COUNT                      1
# IMAGES_PER_GPU                 1
# IMAGE_MAX_DIM                  640
# IMAGE_MIN_DIM                  640
# IMAGE_PADDING                  True
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [640 640   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [56, 56]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           cuy
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                500
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           100
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# Images: 1252
# Classes: ['BG', 'cuy']
# Loading weights  C:\Users\Lenovo\Documents\logs\cuy20210831T2037_resnet101_2500_mae_v1_imagenet\weight_mask_rcnn_cuy_0050.h5
# <module 'visualize' from 'C:\\Users\\Lenovo\\Documents\\GitHub\\Weight-Mask-R-CNN\\visualize.py'>

# %%
image_id = random.choice(dataset.image_ids)
print(image_id)

image, image_meta, gt_class_id, gt_bbox, gt_mask, gt_weight =\
          modellib.load_image_gt_bw(dataset, config, image_id, use_mini_mask=False)
info = dataset.image_info[image_id]
print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, info['weight']))


# Run object detection
results = model.detect_bodyweight([image], verbose=0)

#log("gt_class_id", gt_class_id)
#log("gt_bbox", gt_bbox)
#log("gt_mask", gt_mask)
#log("gt_bodyweight", gt_weight)


    # Display results
ax = get_ax(1)
r = results[0]

log("rois",r['rois'])
log("class_ids",r['class_ids'])
log("bodyweight",r['bodyweight'][0])
log("masks",r['masks'])
print(r['bodyweight'])
print(np.size(r['bodyweight']))
visualize.display_instances_bw(image, r['rois'], r['masks'] ,r['bodyweight'], r['class_ids'], 
                              dataset.class_names, r['scores'], ax=ax,
                              title="Predictions")
# Out:
# 78
# image ID: dataset.DSC_0393_augm_2 (78) 1229.5041595763437
# resnet101
# (640, 640, 3)
# rois                     shape: (1, 4)                min:  274.00000  max:  607.00000
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000
# bodyweight               shape: (1,)                  min: 1203.81335  max: 1203.81335
# masks                    shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# [[1203.8134]]
# 1
# 1

# %%
#from sklearn.metrics import mean_squared_error
y_true, y_pred = [] , []
for image_id in dataset.image_ids:
    #print(image_id)
    image, image_meta, gt_class_id, gt_bbox, gt_mask, gt_weight =\
          modellib.load_image_gt_keypoints(dataset, config, image_id, use_mini_mask=False)
    info = dataset.image_info[image_id]
    #print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, info['weight']))
    # Run object detection
    results = model.detect_bodyweight([image], verbose=0)
    r = results[0]
    if(np.size(r['bodyweight']) == 1):
        y_true.append(info['weight'])
        y_pred.append(r['bodyweight'][0][0])
    #print(r['bodyweight'])

# %%
from sklearn.metrics import r2_score
y_true_array = np.array(y_true)
y_pred_array = np.array(y_pred)
mse = (np.square(abs(y_true_array - y_pred_array))).mean()
rmse = np.sqrt(mse)
r2 = r2_score(y_true_array, y_pred_array)
print('MSE: %s' % mse)
print('RMSE: %s' % rmse)
print('R2: %s' % r2)
# Out:
# MSE: 34068.51423179091
# RMSE: 184.57658094078704
# R2: 0.6897828079001117

# %%
len(y_true_array)
# Out:
# 1246

# %%
#image_id = random.choice(dataset.image_ids)
for image_id in dataset.image_ids:
    image, image_meta, gt_class_id, gt_bbox, gt_mask, gt_weight =\
          modellib.load_image_gt_keypoints(dataset, config, image_id, use_mini_mask=False)
    info = dataset.image_info[image_id]
    print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, 
                                         dataset.image_reference(image_id)))

    # Run object detection
    results = model.detect_keypoint([image], verbose=1)

    # Display results
    ax = get_ax(1)
    r = results[0]
    #visualize.display_instances_bw(image, r['rois'], r['masks'], r['bodyweight'] ,r['class_ids'], 
    #                          dataset.class_names, r['scores'], ax=ax,
    #                          title="Predictions")
    log("gt_class_id", gt_class_id)
    log("gt_bbox", gt_bbox)
    log("gt_mask", gt_mask)
    log("gt_bodyweight", gt_weight)
# Out:
# image ID: dataset.DSC_0301 (0) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0301.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -121.70000  max:  131.30000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.11731  max:  111.64629
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.16871  max:    3.20741
# detections               shape: (1, 10, 6)            min:    0.00000  max:  477.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.66565  max:    3.02974
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  179.00000  max:  478.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1187.00000  max: 1187.00000
# image ID: dataset.DSC_0315 (1) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0315.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  137.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -7.42648  max:  119.39883
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.69070  max:    3.61815
# detections               shape: (1, 10, 6)            min:    0.00000  max:  516.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -2.01995  max:    3.33871
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  172.00000  max:  519.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  968.00000  max:  968.00000
# image ID: dataset.DSC_0320 (2) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0320.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -119.70000  max:  142.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -7.68903  max:  104.86122
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.32013  max:    2.83654
# detections               shape: (1, 10, 6)            min:    0.00000  max:  548.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.90638  max:    2.79062
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  123.00000  max:  544.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  968.00000  max:  968.00000
# image ID: dataset.DSC_0339 (3) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0339.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  143.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.57134  max:  111.78752
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -6.20837  max:    2.52576
# detections               shape: (1, 10, 6)            min:    0.00000  max:  457.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.20982  max:    3.50198
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   82.00000  max:  460.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  884.00000  max:  884.00000
# image ID: dataset.DSC_0369 (4) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0369.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -121.70000  max:  131.30000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.22262  max:  140.22749
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -5.03912  max:    3.41122
# detections               shape: (1, 10, 6)            min:    0.00000  max:  525.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.27163  max:    3.49075
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   74.00000  max:  530.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  623.00000  max:  623.00000
# image ID: dataset.DSC_0376 (5) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0376.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -121.70000  max:  146.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -7.50640  max:  112.01668
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.99257  max:    2.85136
# detections               shape: (1, 10, 6)            min:    0.00000  max:  599.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -2.08875  max:    3.27141
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   37.00000  max:  588.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1134.00000  max: 1134.00000
# image ID: dataset.DSC_0386 (6) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0386.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  133.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -7.95968  max:  107.46190
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.94601  max:    3.04552
# detections               shape: (1, 10, 6)            min:    0.00000  max:  524.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.68443  max:    3.27322
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   47.00000  max:  526.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1252.00000  max: 1252.00000
# image ID: dataset.DSC_0418 (7) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0418.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -116.80000  max:  131.30000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.06732  max:   96.82811
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.88695  max:    4.12298
# detections               shape: (1, 10, 6)            min:    0.00000  max:  563.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.49368  max:    2.85108
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  131.00000  max:  567.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1395.00000  max: 1395.00000
# image ID: dataset.DSC_0421 (8) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0421.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -116.80000  max:  131.30000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.71887  max:  112.09512
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -5.12331  max:    3.06924
# detections               shape: (1, 10, 6)            min:    0.00000  max:  492.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00001  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.55368  max:    3.21205
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  154.00000  max:  488.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  944.00000  max:  944.00000
# image ID: dataset.DSC_0433 (9) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0433.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -120.70000  max:  131.30000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.29661  max:  141.71164
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -5.16738  max:    2.91320
# detections               shape: (1, 10, 6)            min:    0.00000  max:  523.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.13496  max:    3.42480
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  195.00000  max:  521.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1039.00000  max: 1039.00000
# image ID: dataset.DSC_0436 (10) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0436.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  249.00000
# molded_images            shape: (1, 640, 640, 3)      min: -120.70000  max:  125.30000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -5.73039  max:  103.99741
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.58465  max:    2.74132
# detections               shape: (1, 10, 6)            min:    0.00000  max:  493.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -0.69098  max:    2.91412
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:  169.00000  max:  486.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1039.00000  max: 1039.00000
# image ID: dataset.DSC_0474 (11) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0474.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  151.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -7.29946  max:  104.53514
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -5.25294  max:    3.07656
# detections               shape: (1, 10, 6)            min:    0.00000  max:  377.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00018  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.55938  max:    3.30475
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   24.00000  max:  382.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  589.00000  max:  589.00000
# image ID: dataset.DSC_0510 (12) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0510.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  151.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.27945  max:   80.56145
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.53737  max:    3.22823
# detections               shape: (1, 10, 6)            min:    0.00000  max:  289.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.42567  max:    2.72222
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   21.00000  max:  296.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  878.00000  max:  878.00000
# image ID: dataset.DSC_0523 (13) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0523.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  149.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -6.77036  max:  128.02296
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.19237  max:    3.11987
# detections               shape: (1, 10, 6)            min:    0.00000  max:  357.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -0.61641  max:    2.94989
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   94.00000  max:  356.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  837.00000  max:  837.00000
# image ID: dataset.DSC_0525 (14) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0525.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  151.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -7.03800  max:  122.11279
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.50882  max:    3.62762
# detections               shape: (1, 10, 6)            min:    0.00000  max:  270.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.18851  max:    2.84333
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   72.00000  max:  269.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  646.00000  max:  646.00000
# image ID: dataset.DSC_0532 (15) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0532.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    0.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -123.70000  max:  146.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -5.66781  max:  108.63863
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -3.99668  max:    3.12482
# detections               shape: (1, 10, 6)            min:    0.00000  max:  593.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.60873  max:    3.05237
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   46.00000  max:  590.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min:  992.00000  max:  992.00000
# image ID: dataset.DSC_0537 (16) C:\Users\Lenovo\Documents\GitHub\Keypoints-of-humanpose-with-Mask-R-CNN\dataset/cuy\val\DSC_0537.jpg
# Processing 1 images
# image                    shape: (640, 640, 3)         min:    7.00000  max:  255.00000
# molded_images            shape: (1, 640, 640, 3)      min: -116.70000  max:  151.10000
# image_metas              shape: (1, 10)               min:    0.00000  max:  640.00000
# windows                  shape: (1, 4)                min:    0.00000  max:  640.00000
# rpn_class                shape: (1, 102300, 2)        min:    0.00000  max:    1.00000
# rpn_bbox                 shape: (1, 102300, 4)        min:   -5.41449  max:   95.43990
# rois                     shape: (1, 1000, 4)          min:    0.00000  max:    1.00000
# mrcnn_class              shape: (1, 1000, 2)          min:    0.00000  max:    1.00000
# mrcnn_bbox               shape: (1, 1000, 2, 4)       min:   -4.11699  max:    3.10579
# detections               shape: (1, 10, 6)            min:    0.00000  max:  566.00000
# mrcnn_mask               shape: (1, 10, 56, 56, 2)    min:    0.00000  max:    1.00000
# mrcnn_bodyweight         shape: (1, 1000, 2)          min:   -1.53750  max:    3.40008
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000
# gt_bbox                  shape: (1, 4)                min:   45.00000  max:  562.00000
# gt_mask                  shape: (640, 640, 1)         min:    0.00000  max:    1.00000
# gt_bodyweight            shape: (1,)                  min: 1159.00000  max: 1159.00000

# %%
r['bodyweight'].shape
# Out:
# (1, 2)

# %%
# Test on a random image
image_id = random.choice(val_dataset_keypoints.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask, gt_keypoint =\
    modellib.load_image_gt_keypoints(val_dataset_keypoints, inference_config, 
                           image_id, augment=False,use_mini_mask=inference_config.USE_MINI_MASK)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)
log("gt_keypoint", gt_keypoint)

log("rois",r['rois'])
log("keypoints",r['keypoints'])
log("class_ids",r['class_ids'])
log("keypoints",r['keypoints'])
log("masks",r['masks'])
visualize.display_keypoints(original_image,gt_bbox,gt_keypoint,gt_class_id,val_dataset_keypoints.class_names，skeleton = inference_config.LIMBS)
if(inference_config.USE_MINI_MASK):
    gt_mask = utils.expand_mask(gt_bbox,gt_mask,original_image.shape)
visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            val_dataset_keypoints.class_names,)
